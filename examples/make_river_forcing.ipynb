# %%
# test the new build rivers

# %%
import fvtools.prepro.BuildRivers as br
info = br.get_input()

# %%
# In this case, we make river forcing for the new Trøndelag model

# %%
info
# Out:
# {'iloc': 'edge',
#  'land buffer': 1500,
#  'buffer domain ratio': 0.1,
#  'obc buffer': 5000,
#  'min_depth': 3,
#  'Isplit': 8,
#  'tideamp': 1,
#  'plot': True,
#  'compile river': True,
#  'rivertemp': 'riverdata/',
#  'runoff': 'riverdata/Niva_1990-2024_2018v20.05/',
#  'riverpositions': '../prosjekter/PO5-6/river_positions_PO56.csv',
#  'minrcoef': 0.3,
#  'river_projection': 'epsg:32633',
#  'grid_projection': 'epsg:32632'}

# %%
# %matplotlib tk
br.main('2023-6-1', '2024-6-1', list(range(91, 147)), '../prosjekter/PO5-6/M_utm32.npy', info = info)
# Out:
# ----------------------------------------------------------------------------
#                        BuildRivers: PO56
# ----------------------------------------------------------------------------
# Compute grid connectivity and identify landpoints
# - Identify boundary nodes and cells...
#   - build triangulation
#   - find neighbors
#   - isolate the nodes and cells in the domain from those near the boundary
#   - seperate land boundaries from the obc
#
# Subset the river database to cover the model domain
# - Adjust river positions and remove rivers that do not drain to the model domain
#  - iteration 1
# - Remove rivers that discharge within 5000 m from the open boundary
# - Determine runoff from rivers by the rivers catchment area
#
# Add temperature profiles to the rivers
# - read temperature databases from riverdata/, calculate the river climatology for each watershed
# - Add observed temperatures to the rivers where available
# ...

# %%
# If you moved rivers manually, and want to move them again - then you can continue from the first pass
info['riverpositions'] = '../prosjekter/PO5-6/river_positions_PO56.csv'

# %%
# %matplotlib tk
br.main('2023-6-1', '2024-6-1', list(range(91, 147)), '../prosjekter/PO5-6/M_utm32.npy', info = info)
